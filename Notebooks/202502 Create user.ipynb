# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from django.db.models import Sum, Max, Subquery, Q, F, Avg, Count, Min, Max, Sum, F, Q
from django.db.models import Value, IntegerField
from django.db.models.functions import Coalesce, Greatest, Floor
from account.models import User
from booth.models import Transaction, Participation
from player.models import Player
import random
import pandas as pd

# %%
df = pd.read_csv('user.csv')
df = df.iloc[41:]
df
# Out:
#       id                                           password  is_superuser  \
# 41   942  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 42   943  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 43   944  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 44   945  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 45   946  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# ..   ...                                                ...           ...
# 641  895  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 642  896  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 643  897  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 644  898  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
# 645  899  pbkdf2_sha256$390000$Rd0scfcAkVNSrZXBMvcreU$v+...         False
#
#     username  is_staff  is_active user_type first_name last_name  nick_name
# 41        Z1     False       True        oc         Z1        Z1        NaN
# 42        Z2     False       True        oc         Z2        Z2        NaN
# 43        Z3     False       True        oc         Z3        Z3        NaN
# 44        Z4     False       True        oc         Z4        Z4        NaN
# 45        Z5     False       True        oc         Z5        Z5        NaN
# ..       ...       ...        ...       ...        ...       ...        ...
# 641  vip_895     False       True       vip        VIP       895        NaN
# 642  vip_896     False       True       vip        VIP       896        NaN
# 643  vip_897     False       True       vip        VIP       897        NaN
# 644  vip_898     False       True       vip        VIP       898        NaN
# 645  vip_899     False       True       vip        VIP       899        NaN
#
# [605 rows x 10 columns]

# %%
for i, r in df.iterrows():
    row = r.to_dict()
    u = User(**row)
    u.save()
